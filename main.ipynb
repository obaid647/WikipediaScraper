# %%
#imports
from TopCA import TopCA
from TopUSA import TopUSA
from TopCN import TopCN

# %%
#print list
print("""Country List:
- Canada
- USA""")
# Out:
# Country List:
# - Canada
# - USA

# %%
#ask for input
userInput = input("Which country (Press [enter] to exit): ")

# %%
#while user has not pressed enter key
while (userInput != ""):
    
    if (userInput == "Canada"):
        df = TopCA()
        display(df)
    elif (userInput == "USA"):
        df = TopUSA()
        display(df)
    elif (userInput == "China"):
        df = TopCN()
        display(df)
    #wrong input
    else:
        print("Please enter valid country.")
    
    #display df
    #df
    
    #ask user for input
    userInput = input("Which country (Press [enter] to exit): ")
# Out:
# <table class="wikitable sortable" style="text-align:right;">
# <tbody><tr>
# <th align="center">Rank</th>
# <th align="center">List Rank</th>
# <th align="center">Name</th>
# <th align="center">Headquarters</th>
# <th align="center">Revenue (US$ Million)</th>
# <th align="center">Profit (US$ Million)
# </th>
# <th>Assets (US$ Million)
# </th>
# <th>Employees</th>
# <th align="center">Industry</th>
# <th align="center">Ownership
# </th></tr>
# <tr>
# <td>1</td>
# <td>3</td>
# <td align="left"><a href="/wiki/State_Grid_Corporation_of_China" title="State Grid Corporation of China">State Grid Corporation of China</a></td>
# <td align="left"><a href="/wiki/Beijing" title="Beijing">Beijing</a></td>
# <td>460,616.9</td>
# <td>7,137.8
# </td>
# <td>735,429.9
# </td>
# <td>871,145</td>
# <td align="left"><a href="/wiki/Electric_power_industry" title="Electric power industry">Electric power industry</a></td>
# ...
